# %% [markdown]
# # Start here
#
# Welcome to your RPL GPU Platform session. This notebook opens automatically so you can verify the workspace before starting your work.
#
# ## Important
#
# - Work in `/work`.
# - Storage is temporary. Commit and push important changes before stopping the session.
# - Use the Git panel in the left sidebar for clone, diff, commit, pull, and push.
# - Use the terminal for advanced commands.

# %%
# !pwd
# !ls -la

# %% [markdown]
# ## Check GPU
#
# Run this cell to confirm the GPU is visible inside the session.

# %%
# !nvidia-smi

# %% [markdown]
# ## Check Python environment
#
# These packages are available by default.

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib

print('Python:', sys.version.split()[0])
print('NumPy:', np.__version__)
print('Pandas:', pd.__version__)
print('Matplotlib:', matplotlib.__version__)

# %% [markdown]
# ## Git quick start
#
# Before committing, set your identity in a terminal:
#
# ```bash
# git config --global user.name "Your Name"
# git config --global user.email "you@example.com"
# ```
#
# For private repositories or pushing changes, use your Git provider token or SSH setup.
